# %% [markdown]
# # LangChain Model Integration Tutorial
#
# This notebook demonstrates how to integrate and query models from different LLM providers using LangChain. We will cover:
# 1. **Google Gemini** integration
# 2. **OpenAI** integration
# 3. **Groq** (Llama 3) integration
# 4. **Streaming** responses
# 5. **Batching** queries

# %%
# Load environment variables from .env file
from dotenv import load_dotenv
import os

load_dotenv()
print("Environment variables loaded successfully!")
# Out:
# Environment variables loaded successfully!

# %% [markdown]
# ## 1. Google Gemini Integration
#
# Uses `ChatGoogleGenerativeAI` from the `langchain-google-genai` package.

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

if os.getenv("GOOGLE_API_KEY"):
    gemini_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
    response = gemini_model.invoke("What is the capital of France?")
    print("Gemini Response:", response.content)
else:
    print("GOOGLE_API_KEY is not set.")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Gemini Response: Paris.

# %% [markdown]
# ## 2. OpenAI Integration
#
# Uses `ChatOpenAI` from the `langchain-openai` package.

# %%
from langchain_openai import ChatOpenAI

if os.getenv("OPENAI_API_KEY"):
    openai_model = ChatOpenAI(model="gpt-4o-mini")
    response = openai_model.invoke("What is the capital of Japan?")
    print("OpenAI Response:", response.content)
else:
    print("OPENAI_API_KEY is not set.")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[7], line 5
#       1 from langchain_openai import ChatOpenAI
#       2
#       3 if os.getenv("OPENAI_API_KEY"):
#       4     openai_model = ChatOpenAI(model="gpt-4o-mini")
# ----> 5     response = openai_model.invoke("What is the capital of Japan?")
#       6     print("OpenAI Response:", response.content)
#       7 else:
#       8     print("OPENAI_API_KEY is not set.")
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:476, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     462 @override
#     463 def invoke(
#     464     self,
#    (...)    469     **kwargs: Any,
#     470 ) -> AIMessage:
#     471     config = ensure_config(config)
#     472     return cast(
#     473         "AIMessage",
#     474         cast(
#     475             "ChatGeneration",
# --> 476             self.generate_prompt(
#     477                 [self._convert_input(input)],
#     478                 stop=stop,
#     479                 callbacks=config.get("callbacks"),
#     480                 tags=config.get("tags"),
#     481                 metadata=config.get("metadata"),
#     482                 run_name=config.get("run_name"),
#     483                 run_id=config.pop("run_id", None),
#     484                 **kwargs,
#     485             ).generations[0][0],
#     486         ).message,
#     487     )
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1849, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1840 @override
#    1841 def generate_prompt(
#    1842     self,
#    (...)   1846     **kwargs: Any,
#    1847 ) -> LLMResult:
#    1848     prompt_messages = [p.to_messages() for p in prompts]
# -> 1849     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1656, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#    1653 for i, m in enumerate(input_messages):
#    1654     try:
#    1655         results.append(
# -> 1656             self._generate_with_cache(
#    1657                 m,
#    1658                 stop=stop,
#    1659                 run_manager=run_managers[i] if run_managers else None,
#    1660                 **kwargs,
#    1661             )
#    1662         )
#    1663     except BaseException as e:
#    1664         if run_managers:
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_core\language_models\chat_models.py:1994, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1992     result = generate_from_stream(iter(chunks))
#    1993 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1994     result = self._generate(
#    1995         messages, stop=stop, run_manager=run_manager, **kwargs
#    1996     )
#    1997 else:
#    1998     result = self._generate(messages, stop=stop, **kwargs)
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1752, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1750     _handle_openai_bad_request(e)
#    1751 except openai.APIError as e:
# -> 1752     _handle_openai_api_error(e)
#    1753 except Exception as e:
#    1754     if raw_response is not None and hasattr(raw_response, "http_response"):
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\langchain_openai\chat_models\base.py:1747, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1740         return _construct_lc_result_from_responses_api(
#    1741             response,
#    1742             schema=original_schema_obj,
#    1743             metadata=generation_info,
#    1744             output_version=self.output_version,
#    1745         )
#    1746     else:
# -> 1747         raw_response = self.client.with_raw_response.create(**payload)
#    1748         response = raw_response.parse()
#    1749 except openai.BadRequestError as e:
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\openai\_legacy_response.py:369, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     365 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     367 kwargs["extra_headers"] = extra_headers
# --> 369 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\openai\_utils\_utils.py:298, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     296             msg = f"Missing required argument: {quote(missing[0])}"
#     297     raise TypeError(msg)
# --> 298 return func(*args, **kwargs)
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1296, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1247 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1248 def create(
#    1249     self,
#    (...)   1293     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1294 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1295     validate_response_format(response_format)
# -> 1296     return self._post(
#    1297         "/chat/completions",
#    1298         body=maybe_transform(
#    1299             {
#    1300                 "messages": messages,
#    1301                 "model": model,
#    1302                 "audio": audio,
#    1303                 "frequency_penalty": frequency_penalty,
#    1304                 "function_call": function_call,
#    1305                 "functions": functions,
#    1306                 "logit_bias": logit_bias,
#    1307                 "logprobs": logprobs,
#    1308                 "max_completion_tokens": max_completion_tokens,
#    1309                 "max_tokens": max_tokens,
#    1310                 "metadata": metadata,
#    1311                 "modalities": modalities,
#    1312                 "moderation": moderation,
#    1313                 "n": n,
#    1314                 "parallel_tool_calls": parallel_tool_calls,
#    1315                 "prediction": prediction,
#    1316                 "presence_penalty": presence_penalty,
#    1317                 "prompt_cache_key": prompt_cache_key,
#    1318                 "prompt_cache_options": prompt_cache_options,
#    1319                 "prompt_cache_retention": prompt_cache_retention,
#    1320                 "reasoning_effort": reasoning_effort,
#    1321                 "response_format": response_format,
#    1322                 "safety_identifier": safety_identifier,
#    1323                 "seed": seed,
#    1324                 "service_tier": service_tier,
#    1325                 "stop": stop,
#    1326                 "store": store,
#    1327                 "stream": stream,
#    1328                 "stream_options": stream_options,
#    1329                 "temperature": temperature,
#    1330                 "tool_choice": tool_choice,
#    1331                 "tools": tools,
#    1332                 "top_logprobs": top_logprobs,
#    1333                 "top_p": top_p,
#    1334                 "user": user,
#    1335                 "verbosity": verbosity,
#    1336                 "web_search_options": web_search_options,
#    1337             },
#    1338             completion_create_params.CompletionCreateParamsStreaming
#    1339             if stream
#    1340             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1341         ),
#    1342         options=make_request_options(
#    1343             extra_headers=extra_headers,
#    1344             extra_query=extra_query,
#    1345             extra_body=extra_body,
#    1346             timeout=timeout,
#    1347             security={"bearer_auth": True},
#    1348         ),
#    1349         cast_to=ChatCompletion,
#    1350         stream=stream or False,
#    1351         stream_cls=Stream[ChatCompletionChunk],
#    1352     )
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\openai\_base_client.py:1375, in SyncAPIClient.post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1366     warnings.warn(
#    1367         "Passing raw bytes as `body` is deprecated and will be removed in a future version. "
#    1368         "Please pass raw bytes via the `content` parameter instead.",
#    1369         DeprecationWarning,
#    1370         stacklevel=2,
#    1371     )
#    1372 opts = FinalRequestOptions.construct(
#    1373     method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1374 )
# -> 1375 return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File ~\Desktop\langchain\.venv\Lib\site-packages\openai\_base_client.py:1148, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1145             err.response.read()
#    1147         log.debug("Re-raising status error")
# -> 1148         raise self._make_status_error_from_response(err.response) from None
#    1150     break
#    1152 assert response is not None, "could not resolve response (should never happen)"
#
# RateLimitError: Error code: 429 - {'error': {'message': 'You have no credits remaining. Add credits to continue using the API at https://platform.openai.com/settings/organization/billing/.', 'type': 'insufficient_quota', 'param': None, 'code': 'credit_balance_exhausted'}}

# %% [markdown]
# ## 3. Groq (Llama 3) Integration
#
# Uses `ChatGroq` from the `langchain-groq` package.

# %%
from langchain_groq import ChatGroq

if os.getenv("GROQ_API_KEY"):
    groq_model = ChatGroq(model="llama3-8b-8192")
    response = groq_model.invoke("What is the capital of Germany?")
    print("Groq Response:", response.content)
else:
    print("GROQ_API_KEY is not set.")
# Out:
# GROQ_API_KEY is not set.

# %% [markdown]
# ## 4. Streaming Responses
#
# Streaming allows you to fetch chunks of the model's response in real-time rather than waiting for the entire output.

# %%
if os.getenv("GOOGLE_API_KEY"):
    print("Streaming response from Gemini:")
    gemini_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
    for chunk in gemini_model.stream("Write a 3-sentence story about a friendly robot."):
        print(chunk.content, end="", flush=True)
else:
    print("GOOGLE_API_KEY is not set.")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Streaming response from Gemini:
# Unit 734, or "Sparky" as the children called him, loved to
#  greet everyone with a cheerful whir and a bright LED smile. He spent his days helping in the community garden, carefully watering plants and offering a comforting metallic pat to anyone feeling down. His gentle nature made him the most beloved resident of the
#  town, always ready with a kind gesture and a helpful hand.

# %% [markdown]
# ## 5. Batching Queries
#
# Batching allows you to send multiple prompts in parallel to save time and optimize throughput.

# %%
if os.getenv("GOOGLE_API_KEY"):
    gemini_model = ChatGoogleGenerativeAI(model="gemini-2.5-flash")
    prompts = [
        "Tell me a joke about coding.",
        "Tell me a joke about physics.",
        "Tell me a joke about mathematics."
    ]
    print("Sending batch requests...")
    responses = gemini_model.batch(prompts)
    for idx, resp in enumerate(responses):
        print(f"\nResponse {idx+1}: {resp.content.strip()}")
else:
    print("GOOGLE_API_KEY is not set.")
# Out:
# Both GOOGLE_API_KEY and GEMINI_API_KEY are set. Using GOOGLE_API_KEY.
# Sending batch requests...
# Response 1: Why do programmers prefer dark mode?
#
# Because light attracts bugs!
#
# ---
#
# Here's another classic:
#
# A programmer walks into a bar and orders 1.5 beers.
# The bartender says, "I can't serve you 1.5 beers."
# The programmer replies, "Come on, it's a float!"
#
# Response 2: Why did the photon decide to travel alone?
#
# Because it wanted to **travel light!**
#
# Response 3: Why was the math book sad?
#
# Because it had too many problems!
